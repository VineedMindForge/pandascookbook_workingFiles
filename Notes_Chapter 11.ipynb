# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Getting started with matplotlib

# %%
x = [-3,5,7]
y = [10,2,5]
plt.figure(figsize=(15,3))
plt.plot(x,y)
plt.xlim(1,10)
plt.ylim(-3,8)
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Line Plot')
plt.suptitle('Figure Title', size = 20, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Figure Title')

# %%
fig, ax = plt.subplots(figsize=(15,3))
ax.plot(x,y)
ax.set_xlim(0,10)
ax.set_ylim(-3,8)
ax.set_xlabel('X Axis')
ax.set_ylabel('Y Axis')
ax.set_title('Line Plot')
fig.suptitle("Figre Title", size = 20, y = 1.03)
# Out:
# Text(0.5, 1.03, 'Figre Title')

# %%
fig, ax = plt.subplots(nrows = 1, ncols = 1)

# %%
type(fig)
# Out:
# matplotlib.figure.Figure

# %%
type(ax)
# Out:
# matplotlib.axes._axes.Axes

# %%
fig.get_size_inches()
# Out:
# array([6.4, 4.8])

# %%
fig.set_size_inches(14,4)
fig

# %%
fig.axes[0] is ax
# Out:
# True

# %%
fig.set_facecolor('.9')
ax.set_facecolor('.7')
fig

# %%
ax_children = ax.get_children()
ax_children
# Out:
# [<matplotlib.spines.Spine at 0x28c60c40790>,
#  <matplotlib.spines.Spine at 0x28c60c40880>,
#  <matplotlib.spines.Spine at 0x28c60c40970>,
#  <matplotlib.spines.Spine at 0x28c60c40a60>,
#  <matplotlib.axis.XAxis at 0x28c60c407c0>,
#  <matplotlib.axis.YAxis at 0x28c60c40fd0>,
#  Text(0.5, 1.0, ''),
#  Text(0.0, 1.0, ''),
#  Text(1.0, 1.0, ''),
#  <matplotlib.patches.Rectangle at 0x28c60c431c0>]

# %%
spines = ax.spines
spines

# %%
spine_left = spines['left']
spine_left.set_position(('outward',-100))
spine_left.set_linewidth(2)
fig

# %%
spine_bottom = spines['bottom']
spine_bottom.set_visible(False)
fig

# %%
ax.xaxis.grid(True, which='major', linewidth=2,
    color='black', linestyle='--')
ax.xaxis.set_ticks([.2, .4, .55, .93])
ax.xaxis.set_label_text('X Axis', family='Verdana',
    fontsize=15)
ax.set_ylabel('Y Axis', family='Calibri', fontsize=20)
ax.set_yticks([.1, .9])
ax.set_yticklabels(['point 1', 'point 9'], rotation=45)
fig

# %% [markdown]
# # Visualizing data with matplotlib

# %%
movie = pd.read_csv('data/movie.csv')
med_budget = movie.groupby('title_year')['budget'].median()/1e6
med_budget_roll = med_budget.rolling(5, min_periods=1).mean()
med_budget_roll.head()
# Out:
# title_year
# 1916.0    0.385907
# 1920.0    0.242953
# 1925.0    0.243636
# 1927.0    1.682727
# 1929.0    1.421981
# Name: budget, dtype: float64

# %%
years = med_budget_roll.index.values
budget = med_budget_roll.values

# %%
fig,ax = plt.subplots(figsize = (14,5), linewidth = 5, edgecolor = '.5')
ax.plot(years,budget,linestyle = '--',
       linewidth=2, color = '.5', label = 'All Movies')
text_kwargs = dict(fontsize = 20, family = 'cursive')
ax.set_title("Median Movie Budget",**text_kwargs)
text_kwargs = dict(fontsize = 20, family = 'cursive')

# %%
movie_count = movie.groupby('title_year')['budget'].count()
movie_count.tail()
# Out:
# title_year
# 2012.0    191
# 2013.0    208
# 2014.0    221
# 2015.0    192
# 2016.0     86
# Name: budget, dtype: int64

# %%
ct = movie_count.values
